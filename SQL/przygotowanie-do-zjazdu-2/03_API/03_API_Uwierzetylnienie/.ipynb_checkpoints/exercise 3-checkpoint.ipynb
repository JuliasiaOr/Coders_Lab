# %% [markdown]
# # Zadanie 3
#
# Za pomocą biblioteki `requests` pobierz z [https://exchangeratesapi.io/](https://exchangeratesapi.io/) aktualne kursy walut, oraz wyświetl je w formie listy:
#
# ```
# - <KURS 1> EUR/<WALUTA 1>
# - <KURS 2> EUR/<WALUTA 2>
# ...
# ```
#
# Wynik powinien przypominać:
# ```
# - 4.5066 EUR/PLN
# - 1.5319 EUR/CAD
# - 0.86308 EUR/GBP
# ...
# ```

# %%
import requests

url = 'https://api.apilayer.com/exchangerates_data/latest'
headers = {'apikey': 'qLZBrPlMowbv889b0PUB5YchUeh8b7X9'}
res = requests.get(url, headers=headers)

# %%
res.ok
# Out:
# True

# %%
data = res.json()
data
# Out:
# {'success': True,
#  'timestamp': 1674401523,
#  'base': 'EUR',
#  'date': '2023-01-22',
#  'rates': {'AED': 3.995326,
#   'AFN': 96.713864,
#   'ALL': 116.851383,
#   'AMD': 431.011283,
#   'ANG': 1.960098,
#   'AOA': 547.735696,
#   'ARS': 199.161536,
#   'AUD': 1.562412,
#   'AWG': 1.957904,
#   'AZN': 1.85345,
#   'BAM': 1.964934,
#   'BBD': 2.195935,
#   'BDT': 114.904329,
#   'BGN': 1.959911,
#   'BHD': 0.410012,
#   'BIF': 2255.854168,
#   'BMD': 1.087725,
#   'BND': 1.438149,
#   'BOB': 7.514956,
#   'BRL': 5.664656,
#   'BSD': 1.087569,
#   'BTC': 4.7653866e-05,
#   'BTN': 88.264512,
#   'BWP': 13.925651,
#   'BYN': 2.745621,
#   'BYR': 21319.400752,
#   'BZD': 2.192217,
#   'CAD': 1.456844,
#   'CDF': 2206.453469,
#   'CHF': 1.000717,
#   'CLF': 0.032139,
#   'CLP': 886.826063,
#   'CNY': 7.378693,
#   'COP': 5056.374487,
#   'CRC': 612.625246,
#   'CUC': 1.087725,
#   'CUP': 28.8247,
#   'CVE': 110.7762,
#   'CZK': 23.914766,
#   'DJF': 193.310831,
#   'DKK': 7.454507,
#   'DOP': 61.731698,
#   'DZD': 147.921999,
#   'EGP': 32.390241,
#   'ERN': 16.315868,
#   'ETB': 58.332862,
#   'EUR': 1,
#   'FJD': 2.365697,
#   'FKP': 0.877821,
#   'GBP': 0.877976,
#   'GEL': 2.882895,
#   'GGP': 0.877821,
#   'GHS': 13.376451,
#   'GIP': 0.877821,
#   'GMD': 67.820048,
#   'GNF': 9367.829774,
#   'GTQ': 8.537566,
#   'GYD': 227.537801,
#   'HKD': 8.52205,
#   'HNL': 26.830913,
#   'HRK': 7.659978,
#   'HTG': 161.300961,
#   'HUF': 393.463015,
#   'IDR': 16384.720885,
#   'ILS': 3.700226,
#   'IMP': 0.877821,
#   'INR': 88.079854,
#   'IQD': 1587.339145,
#   'IRR': 45521.271887,
#   'ISK': 154.816252,
#   'JEP': 0.877821,
#   'JMD': 166.820865,
#   'JOD': 0.771527,
#   'JPY': 140.920194,
#   'KES': 134.990751,
#   'KGS': 93.631223,
#   'KHR': 4477.612765,
#   'KMF': 494.724351,
#   'KPW': 978.952105,
#   'KRW': 1339.021943,
#   'KWD': 0.332387,
#   'KYD': 0.906353,
#   'KZT': 503.362871,
#   'LAK': 18337.449144,
#   'LBP': 1644.549588,
#   'LKR': 398.059433,
#   'LRD': 170.066145,
#   'LSL': 18.796295,
#   'LTL': 3.211768,
#   'LVL': 0.657954,
#   'LYD': 5.183033,
#   'MAD': 11.09557,
#   'MDL': 20.609919,
#   'MGA': 4645.31216,
#   'MKD': 61.901225,
#   'MMK': 2283.947423,
#   'MNT': 3786.298708,
#   'MOP': 8.774156,
#   'MRO': 388.317469,
#   'MUR': 47.740641,
#   'MVR': 16.696983,
#   'MWK': 1107.994815,
#   'MXN': 20.530587,
#   'MYR': 4.661448,
#   'MZN': 69.429867,
#   'NAD': 18.79629,
#   'NGN': 494.980334,
#   'NIO': 39.738844,
#   'NOK': 10.651945,
#   'NPR': 141.222737,
#   'NZD': 1.680662,
#   'OMR': 0.418769,
#   'PAB': 1.087569,
#   'PEN': 4.200211,
#   'PGK': 3.832952,
#   'PHP': 59.237886,
#   'PKR': 250.010663,
#   'PLN': 4.500624,
#   'PYG': 8075.296154,
#   'QAR': 3.960447,
#   'RON': 4.92261,
#   'RSD': 117.599379,
#   'RUB': 74.237605,
#   'RWF': 1169.407856,
#   'SAR': 4.083155,
#   'SBD': 8.990073,
#   'SCR': 14.977322,
#   'SDG': 623.814018,
#   'SEK': 11.198672,
#   'SGD': 1.435474,
#   'SHP': 1.498236,
#   'SLE': 20.884365,
#   'SLL': 20867.995441,
#   'SOS': 619.463105,
#   'SRD': 35.262402,
#   'STD': 22513.701626,
#   'SVC': 9.516265,
#   'SYP': 2732.935193,
#   'SZL': 18.755517,
#   'THB': 35.50373,
#   'TJS': 11.14694,
#   'TMT': 3.807036,
#   'TND': 3.356178,
#   'TOP': 2.532988,
#   'TRY': 20.403432,
#   'TTD': 7.384549,
#   'TWD': 32.993626,
#   'TZS': 2539.837138,
#   'UAH': 39.961244,
#   'UGX': 3999.932054,
#   'USD': 1.087725,
#   'UYU': 42.693354,
#   'UZS': 12299.772905,
#   'VEF': 2202571.615683,
#   'VES': 21.710462,
#   'VND': 25507.140185,
#   'VUV': 126.186537,
#   'WST': 2.909126,
#   'XAF': 659.043735,
#   'XAG': 0.045433,
#   'XAU': 0.000565,
#   'XCD': 2.93963,
#   'XDR': 0.806075,
#   'XOF': 659.004169,
#   'XPF': 120.197471,
#   'YER': 272.312231,
#   'ZAR': 18.616627,
#   'ZMK': 9790.829926,
#   'ZMW': 20.173666,
#   'ZWL': 350.246854}}

# %%
a = data['rates']
for i in a.items():
    print('-',i[1],'EUR/',i[0])
# Out:
# - 3.995326 EUR/ AED
# - 96.713864 EUR/ AFN
# - 116.851383 EUR/ ALL
# - 431.011283 EUR/ AMD
# - 1.960098 EUR/ ANG
# - 547.735696 EUR/ AOA
# - 199.161536 EUR/ ARS
# - 1.562412 EUR/ AUD
# - 1.957904 EUR/ AWG
# - 1.85345 EUR/ AZN
# - 1.964934 EUR/ BAM
# - 2.195935 EUR/ BBD
# - 114.904329 EUR/ BDT
# - 1.959911 EUR/ BGN
# - 0.410012 EUR/ BHD
# - 2255.854168 EUR/ BIF
# - 1.087725 EUR/ BMD
# - 1.438149 EUR/ BND
# - 7.514956 EUR/ BOB
# - 5.664656 EUR/ BRL
# - 1.087569 EUR/ BSD
# - 4.7653866e-05 EUR/ BTC
# - 88.264512 EUR/ BTN
# - 13.925651 EUR/ BWP
# - 2.745621 EUR/ BYN
# - 21319.400752 EUR/ BYR
# - 2.192217 EUR/ BZD
# - 1.456844 EUR/ CAD
# - 2206.453469 EUR/ CDF
# - 1.000717 EUR/ CHF
# - 0.032139 EUR/ CLF
# - 886.826063 EUR/ CLP
# - 7.378693 EUR/ CNY
# - 5056.374487 EUR/ COP
# - 612.625246 EUR/ CRC
# - 1.087725 EUR/ CUC
# - 28.8247 EUR/ CUP
# - 110.7762 EUR/ CVE
# - 23.914766 EUR/ CZK
# - 193.310831 EUR/ DJF
# - 7.454507 EUR/ DKK
# - 61.731698 EUR/ DOP
# - 147.921999 EUR/ DZD
# - 32.390241 EUR/ EGP
# - 16.315868 EUR/ ERN
# - 58.332862 EUR/ ETB
# - 1 EUR/ EUR
# - 2.365697 EUR/ FJD
# - 0.877821 EUR/ FKP
# - 0.877976 EUR/ GBP
# - 2.882895 EUR/ GEL
# - 0.877821 EUR/ GGP
# - 13.376451 EUR/ GHS
# - 0.877821 EUR/ GIP
# - 67.820048 EUR/ GMD
# - 9367.829774 EUR/ GNF
# - 8.537566 EUR/ GTQ
# - 227.537801 EUR/ GYD
# - 8.52205 EUR/ HKD
# - 26.830913 EUR/ HNL
# - 7.659978 EUR/ HRK
# - 161.300961 EUR/ HTG
# - 393.463015 EUR/ HUF
# - 16384.720885 EUR/ IDR
# - 3.700226 EUR/ ILS
# - 0.877821 EUR/ IMP
# - 88.079854 EUR/ INR
# - 1587.339145 EUR/ IQD
# - 45521.271887 EUR/ IRR
# - 154.816252 EUR/ ISK
# - 0.877821 EUR/ JEP
# - 166.820865 EUR/ JMD
# - 0.771527 EUR/ JOD
# - 140.920194 EUR/ JPY
# - 134.990751 EUR/ KES
# - 93.631223 EUR/ KGS
# - 4477.612765 EUR/ KHR
# - 494.724351 EUR/ KMF
# - 978.952105 EUR/ KPW
# - 1339.021943 EUR/ KRW
# - 0.332387 EUR/ KWD
# - 0.906353 EUR/ KYD
# - 503.362871 EUR/ KZT
# - 18337.449144 EUR/ LAK
# - 1644.549588 EUR/ LBP
# - 398.059433 EUR/ LKR
# - 170.066145 EUR/ LRD
# - 18.796295 EUR/ LSL
# - 3.211768 EUR/ LTL
# - 0.657954 EUR/ LVL
# - 5.183033 EUR/ LYD
# - 11.09557 EUR/ MAD
# - 20.609919 EUR/ MDL
# - 4645.31216 EUR/ MGA
# - 61.901225 EUR/ MKD
# - 2283.947423 EUR/ MMK
# - 3786.298708 EUR/ MNT
# - 8.774156 EUR/ MOP
# - 388.317469 EUR/ MRO
# - 47.740641 EUR/ MUR
# - 16.696983 EUR/ MVR
# - 1107.994815 EUR/ MWK
# - 20.530587 EUR/ MXN
# - 4.661448 EUR/ MYR
# - 69.429867 EUR/ MZN
# - 18.79629 EUR/ NAD
# - 494.980334 EUR/ NGN
# - 39.738844 EUR/ NIO
# - 10.651945 EUR/ NOK
# - 141.222737 EUR/ NPR
# - 1.680662 EUR/ NZD
# - 0.418769 EUR/ OMR
# - 1.087569 EUR/ PAB
# - 4.200211 EUR/ PEN
# - 3.832952 EUR/ PGK
# - 59.237886 EUR/ PHP
# - 250.010663 EUR/ PKR
# - 4.500624 EUR/ PLN
# - 8075.296154 EUR/ PYG
# - 3.960447 EUR/ QAR
# - 4.92261 EUR/ RON
# - 117.599379 EUR/ RSD
# - 74.237605 EUR/ RUB
# - 1169.407856 EUR/ RWF
# - 4.083155 EUR/ SAR
# - 8.990073 EUR/ SBD
# - 14.977322 EUR/ SCR
# - 623.814018 EUR/ SDG
# - 11.198672 EUR/ SEK
# - 1.435474 EUR/ SGD
# - 1.498236 EUR/ SHP
# - 20.884365 EUR/ SLE
# - 20867.995441 EUR/ SLL
# - 619.463105 EUR/ SOS
# - 35.262402 EUR/ SRD
# - 22513.701626 EUR/ STD
# - 9.516265 EUR/ SVC
# - 2732.935193 EUR/ SYP
# - 18.755517 EUR/ SZL
# - 35.50373 EUR/ THB
# - 11.14694 EUR/ TJS
# - 3.807036 EUR/ TMT
# - 3.356178 EUR/ TND
# - 2.532988 EUR/ TOP
# - 20.403432 EUR/ TRY
# - 7.384549 EUR/ TTD
# - 32.993626 EUR/ TWD
# - 2539.837138 EUR/ TZS
# - 39.961244 EUR/ UAH
# - 3999.932054 EUR/ UGX
# - 1.087725 EUR/ USD
# - 42.693354 EUR/ UYU
# - 12299.772905 EUR/ UZS
# - 2202571.615683 EUR/ VEF
# - 21.710462 EUR/ VES
# - 25507.140185 EUR/ VND
# - 126.186537 EUR/ VUV
# - 2.909126 EUR/ WST
# - 659.043735 EUR/ XAF
# - 0.045433 EUR/ XAG
# - 0.000565 EUR/ XAU
# - 2.93963 EUR/ XCD
# - 0.806075 EUR/ XDR
# - 659.004169 EUR/ XOF
# - 120.197471 EUR/ XPF
# - 272.312231 EUR/ YER
# - 18.616627 EUR/ ZAR
# - 9790.829926 EUR/ ZMK
# - 20.173666 EUR/ ZMW
# - 350.246854 EUR/ ZWL
