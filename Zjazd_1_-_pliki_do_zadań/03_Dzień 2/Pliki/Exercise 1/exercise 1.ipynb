# %% [markdown]
# # Zadanie 1
#
# Otwórz plik `wiersz.txt` i wyświetl jego treść, poprzedzając każdą linię stringiem `"Wiersz <NUMER WIERSZA>:   "`.
#
# ### Podpowiedź:
#
# Pętli `for` użyj do przeczytania pliku linia po linii, a oprócz tego stwórz zmienną która przechowa numer linii.
#
# Numer linii możesz wstawić do stringa za pomocą metody `.format(...)` albo składni f-string.

# %%
i = 0 
with open('wiersz.txt') as my_text_file:
  for line in my_text_file.readlines():
    print(line, i, sep='Wiersz:')
    i = i + 1
# Out:
# Stoi na stacji lokomotywa,
# Wiersz:0
# Ciężka, ogromna i pot z niej spływa:
# Wiersz:1
# Tłusta oliwa.
# Wiersz:2
#
# Wiersz:3
# Stoi i sapie, dyszy i dmucha,
# Wiersz:4
# Żar z rozgrzanego jej brzucha bucha:
# Wiersz:5
# Uch - jak gorąco!
# Wiersz:6
# Puff - jak gorąco!
# Wiersz:7
# Uff - jak gorąco!
# Wiersz:8
# Już ledwo sapie, już ledwo zipie,
# Wiersz:9
# A jeszcze palacz węgiel w nią sypie.
# Wiersz:10
# Wagony do niej podoczepiali
# Wiersz:11
# Wielkie i ciężkie, z żelaza, stali,
# Wiersz:12
# I pełno ludzi w każdym wagonie,
# Wiersz:13
# A w jednym krowy, a w drugim konie,
# Wiersz:14
# A w trzecim siedzą same grubasy,
# Wiersz:15
# Siedzą i jedzą tłuste kiełbasy,
# Wiersz:16
# A czwarty wagon pełen bananów,
# Wiersz:17
# A w piątym stoi sześć fortepianów,
# Wiersz:18
# W szóstym armata - o! jaka wielka!
# Wiersz:19
# Pod każdym kołem żelazna belka!
# Wiersz:20
# W siódmym dębowe stoły i szafy,
# Wiersz:21
# W ósmym słoń, niedźwiedź i dwie żyrafy,
# Wiersz:22
# ...
